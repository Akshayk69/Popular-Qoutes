# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
url='https://www.goodreads.com/quotes?page={}'

# %%
def quotes(soup):
    tags=[]
    lst=[i.text.strip() for i in soup.find_all('span',class_='authorOrTitle')]
    quotes=[list(i)[0].strip() for i in soup.find_all('div',class_='quoteText')]
    likes=[int(i.text.split()[0]) for i in soup.find_all('a',class_='smallText')]
    for i in box:
        try:
            tag=i.find('div',class_='greyText smallText left').text.split()[1:]
        except:
            tag=None
        tags.append(tag)
    return pd.DataFrame({'Author':lst,'Quotes':quotes,'Likes':likes,'Tags':tags})

# %%
tab=[]
for i in tqdm(range(1,101)):
    urls=url.format(i)
    html_good=requests.get(urls).text
    soup=BeautifulSoup(html_good,'html.parser')
    box=soup.find_all('div',class_='quoteDetails')
    tab.append(quotes(soup))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [03:16<00:00,  1.96s/it]

# %%
popular_quotes=pd.concat(tab,axis=0)

# %%
popular_quotes.to_csv('popular_quotes.csv')

# %%
pop=pd.read_csv('popular_quotes.csv')

# %%
pop.head(20)
# Out:
#     Unnamed: 0                 Author  \
# 0            0            Oscar Wilde
# 1            1         Marilyn Monroe
# 2            2        Albert Einstein
# 3            3            Frank Zappa
# 4            4  Marcus Tullius Cicero
# 5            5      Bernard M. Baruch
# 6            6      William W. Purkey
# 7            7              Dr. Seuss
# 8            8               Mae West
# 9            9         Mahatma Gandhi
# 10          10           Robert Frost
# 11          11          J.K. Rowling,
# 12          12           Albert Camus
# 13          13             Mark Twain
# 14          14            C.S. Lewis,
# 15          15           Maya Angelou
# 16          16         Elbert Hubbard
# 17          17            Oscar Wilde
# 18          18            Oscar Wilde
# 19          19         Mahatma Gandhi
#
#                                                Quotes   Likes  \
# 0      “Be yourself; everyone else is already taken.”  160751
# 1   “I'm selfish, impatient and a little insecure....  157307
# 2   “Two things are infinite: the universe and hum...  139694
# 3                    “So many books, so little time.”  137658
# 4   “A room without books is like a body without a...  127361
# 5   “Be who you are and say what you feel, because...  124911
# 6   “You've gotta dance like there's nobody watching,  123021
# 7   “You know you're in love when you can't fall a...  119958
# 8   “You only live once, but if you do it right, o...  112737
# 9   “Be the change that you wish to see in the wor...  110418
# 10  “In three words I can sum up everything I've l...  104626
# 11  “If you want to know what a man's like, take a...   99017
# 12       “Don’t walk in front of me… I may not follow   89028
# 13  “If you tell the truth, you don't have to reme...   87565
# 14  “Friendship ... is born at the moment when one...   85907
# 15  “I've learned that people will forget what you...   83437
# 16  “A friend is someone who knows all about you a...   80972
# 17  “To live is the rarest thing in the world. Mos...   78432
# 18  “Always forgive your enemies; nothing annoys t...   78414
# 19  “Live as if you were to die tomorrow. Learn as...   75291
#
#                                                  Tags
# 0   ['attributed-no-source,', 'be-yourself,', 'gil...
# 1   ['attributed-no-source,', 'best,', 'life,', 'l...
# 2   ['attributed-no-source,', 'human-nature,', 'hu...
# 3                                 ['books,', 'humor']
# 4   ['attributed-no-source,', 'books,', 'simile,',...
# 5   ['ataraxy,', 'be-yourself,', 'confidence,', 'f...
# 6   ['dance,', 'heaven,', 'hurt,', 'inspirational,...
# 7   ['attributed-no-source,', 'dreams,', 'love,', ...
# 8                                  ['humor,', 'life']
# 9   ['action,', 'change,', 'inspirational,', 'phil...
# 10                                           ['life']
# 11                   ['from-charles-bayard-mitchell']
# 12  ['attributed-no-source,', 'friends,', 'friends...
# 13            ['lies,', 'lying,', 'memory,', 'truth']
# 14                                     ['friendship']
# 15                                                NaN
# 16   ['friend,', 'friendship,', 'knowledge,', 'love']
# 17                                           ['life']
# 18  ['attributed-no-source,', 'enemies,', 'forgive...
# 19  ['carpe-diem,', 'education,', 'inspirational,'...

# %%
pop.iloc[18,2]
# Out:
# '“Always forgive your enemies; nothing annoys them so much.”'
